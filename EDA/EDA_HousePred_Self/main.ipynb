# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('House Price India.csv')
pd.set_option('display.max_columns', None) 
pd.set_option('display.max_colwidth', None)
pd.set_option('display.width', 100)   
df.head(10)
df.tail(10)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  living area  lot area  \
# 14610  6762828349  42734                   4                 2.75         1810      7350
# 14611  6762828783  42734                   3                 1.75         1350      7686
# 14612  6762828856  42734                   3                 1.00         1180      5350
# 14613  6762829600  42734                   3                 1.00         1400     10425
# 14614  6762829669  42734                   3                 1.75         1590      7931
# 14615  6762830250  42734                   2                 1.50         1556     20000
# 14616  6762830339  42734                   3                 2.00         1680      7000
# 14617  6762830618  42734                   2                 1.00         1070      6120
# 14618  6762830709  42734                   4                 1.00         1030      6621
# ...

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms   living area  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000  14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583   2098.262996
# std    6.237575e+03     67.347991            0.938719             0.769934    928.275721
# min    6.762810e+09  42491.000000            1.000000             0.500000    370.000000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000   1440.000000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000   1930.000000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000   2570.000000
# max    6.762832e+09  42734.000000           33.000000             8.000000  13540.000000
#
#            lot area  number of floors  waterfront present  number of views  \
# count  1.462000e+04      14620.000000        14620.000000     14620.000000
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
# ...

# %%
df=df.drop(['id','Date'],axis='columns')
df
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  number of floors  \
# 0                       5                 2.50         3650      9050               2.0
# 1                       4                 2.50         2920      4000               1.5
# 2                       5                 2.75         2910      9480               1.5
# 3                       4                 2.50         3310     42998               2.0
# 4                       3                 2.00         2710      4500               1.5
# ...                   ...                  ...          ...       ...               ...
# 14615                   2                 1.50         1556     20000               1.0
# 14616                   3                 2.00         1680      7000               1.5
# 14617                   2                 1.00         1070      6120               1.0
# 14618                   4                 1.00         1030      6621               1.0
# ...

# %%
from scipy.stats import zscore

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.boxplot(x='number of bathrooms', data=df)
# Out:
# <Axes: xlabel='number of bathrooms'>

# %%
df[(np.abs(zscore(df['number of bathrooms'])) > 3)]
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  number of floors  \
# 76                      7                  8.0        13540    307752               3.0
# 161                     5                  5.0         4490     10279               2.0
# 243                     7                  4.5         6210      8856               2.5
# 244                     5                  4.5         4270      8076               2.0
# 268                     9                  4.5         3830      6988               2.5
# ...                   ...                  ...          ...       ...               ...
# 13945                   5                  4.5         4690      6705               2.0
# 14016                   4                  4.5         5270     12195               2.0
# 14339                   4                  4.5         4920    270236               2.0
# 14397                   5                  4.5         4350     13405               2.0
# ...

# %%
sns.boxplot(x='number of bedrooms', data=df)
# Out:
# <Axes: xlabel='number of bedrooms'>

# %%
df[(np.abs(zscore(df['number of bedrooms'])) > 3)]
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  number of floors  \
# 76                      7                 8.00        13540    307752               3.0
# 243                     7                 4.50         6210      8856               2.5
# 268                     9                 4.50         3830      6988               2.5
# 275                     7                 5.75         3700      7647               2.0
# 624                     7                 4.00         3440      8100               2.0
# 785                     7                 3.50         2870     29699               1.0
# 1512                    8                 3.50         4440      6480               2.0
# 1519                    7                 4.00         3150     34830               1.0
# 1553                    7                 4.50         4140      9066               1.0
# 1706                    7                 4.50         4290     37607               1.5
# ...

# %%
sns.boxplot(x='Area of the house(excluding basement)', data=df)
# Out:
# <Axes: xlabel='Area of the house(excluding basement)'>

# %%
df[(np.abs(zscore(df['Area of the house(excluding basement)'])) > 3)]
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  number of floors  \
# 76                      7                 8.00        13540    307752               3.0
# 79                      4                 2.50         4340    141570               2.5
# 160                     5                 4.00         4510     15175               2.0
# 243                     7                 4.50         6210      8856               2.5
# 247                     4                 4.00         4460    103382               2.0
# ...                   ...                  ...          ...       ...               ...
# 13929                   4                 3.50         5830    131116               2.0
# 13930                   4                 3.25         4750     62365               2.0
# 14017                   4                 3.25         5080     27755               2.0
# 14086                   4                 3.50         5844     10766               2.0
# ...

# %%
sns.boxplot(x='living area', data=df)
# Out:
# <Axes: xlabel='living area'>

# %%
df[(np.abs(zscore(df['living area'])) > 3)]
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  number of floors  \
# 76                      7                 8.00        13540    307752               3.0
# 243                     7                 4.50         6210      8856               2.5
# 418                     5                 6.50         7270    130017               2.0
# 419                     5                 4.50         5190      5432               2.0
# 421                     4                 4.25         5860     52889               2.0
# ...                   ...                  ...          ...       ...               ...
# 14216                   4                 4.00         5780      7173               2.0
# 14339                   4                 4.50         4920    270236               2.0
# 14431                   5                 3.50         4890     12039               2.0
# 14468                   5                 3.25         5620     12672               2.0
# ...

# %%
sns.boxplot(x='number of floors',data=df)
# Out:
# <Axes: xlabel='number of floors'>

# %%
df[(np.abs(zscore(df['number of floors'])) > 3)]
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  number of floors  \
# 3547                    3                 2.50         1400      1312               3.5
# 6198                    3                 3.00         1440      4670               3.5
# 9127                    2                 2.75         1310      1268               3.5
# 10916                   8                 4.00         7710     11750               3.5
#
#        waterfront present  number of views  condition of the house  grade of the house  \
# 3547                    0                0                       3                   8
# 6198                    0                2                       3                   8
# 9127                    0                0                       3                   8
# 10916                   0                0                       5                  12
#
# ...

# %%
df = df[(np.abs(zscore(df['number of bathrooms'])) < 3)]
df = df[(np.abs(zscore(df['number of bedrooms'])) < 3)]
df = df[(np.abs(zscore(df['Area of the house(excluding basement)'])) < 3)]
df = df[(np.abs(zscore(df['living area'])) < 3)]
df
# Out:
#        number of bedrooms  number of bathrooms  living area  lot area  number of floors  \
# 0                       5                 2.50         3650      9050               2.0
# 1                       4                 2.50         2920      4000               1.5
# 2                       5                 2.75         2910      9480               1.5
# 3                       4                 2.50         3310     42998               2.0
# 4                       3                 2.00         2710      4500               1.5
# ...                   ...                  ...          ...       ...               ...
# 14615                   2                 1.50         1556     20000               1.0
# 14616                   3                 2.00         1680      7000               1.5
# 14617                   2                 1.00         1070      6120               1.0
# 14618                   4                 1.00         1030      6621               1.0
# ...

# %%
df['Renovation Year'].value_counts()
# Out:
# Renovation Year
# 0       13552
# 2014       76
# 2013       30
# 2003       23
# 2006       22
#         ...
# 1946        1
# 1967        1
# 1944        1
# 1959        1
# 1962        1
# Name: count, Length: 68, dtype: int64

# %%
df=df.drop(['Renovation Year','Postal Code','Lattitude','Longitude'],axis='columns')

# %%
df['waterfront present'].value_counts()
# Out:
# waterfront present
# 0    14101
# 1       88
# Name: count, dtype: int64

# %%
sns.barplot(data=df,x='waterfront present',y='Price')
# Out:
# <Axes: xlabel='waterfront present', ylabel='Price'>

# %%
df['Number of schools nearby'].value_counts()
# Out:
# Number of schools nearby
# 3    4819
# 2    4728
# 1    4642
# Name: count, dtype: int64

# %%
df['Distance from the airport'].value_counts()
# Out:
# Distance from the airport
# 54    506
# 70    496
# 64    482
# 50    479
# 56    477
# 60    477
# 79    472
# 69    469
# 59    468
# 67    466
# 53    466
# 55    460
# 62    458
# 66    458
# 72    457
# 57    457
# 74    457
# 58    456
# 71    450
# 73    450
# 78    449
# 75    448
# 76    447
# 77    445
# 80    441
# 68    440
# 63    438
# 65    436
# 52    430
# 61    429
# 51    425
# Name: count, dtype: int64

# %%
sns.barplot(data=df,x='Number of schools nearby',y='Price')
# Out:
# <Axes: xlabel='Number of schools nearby', ylabel='Price'>

# %%
sns.barplot(data=df,x='Distance from the airport',y='Price')
# Out:
# <Axes: xlabel='Distance from the airport', ylabel='Price'>

# %%
sns.barplot(data=df,x='condition of the house',y='Price')
# Out:
# <Axes: xlabel='condition of the house', ylabel='Price'>

# %%
df['condition of the house'].value_counts()
# Out:
# condition of the house
# 3    9023
# 4    3802
# 5    1248
# 2      98
# 1      18
# Name: count, dtype: int64

# %%
sns.barplot(data=df,x='Built Year',y='Price')
# Out:
# <Axes: xlabel='Built Year', ylabel='Price'>

# %%
sns.boxplot(data=df,x='lot area')
# Out:
# <Axes: xlabel='lot area'>

# %%
sns.barplot(data=df,x='grade of the house',y='Price')
# Out:
# <Axes: xlabel='grade of the house', ylabel='Price'>

# %%
df=df.drop(['lot area','Built Year','lot_area_renov','Number of schools nearby','Distance from the airport','waterfront present','condition of the house'],axis='columns')
df
# Out:
#        number of bedrooms  number of bathrooms  living area  number of floors  number of views  \
# 0                       5                 2.50         3650               2.0                4
# 1                       4                 2.50         2920               1.5                0
# 2                       5                 2.75         2910               1.5                0
# 3                       4                 2.50         3310               2.0                0
# 4                       3                 2.00         2710               1.5                0
# ...                   ...                  ...          ...               ...              ...
# 14615                   2                 1.50         1556               1.0                0
# 14616                   3                 2.00         1680               1.5                0
# 14617                   2                 1.00         1070               1.0                0
# ...

# %%
plt.figure(figsize=(15,15))
sns.heatmap(df.corr(),linewidths=0.5,annot=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
X = df.drop(['Price'], axis='columns')
y = df['Price']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=10)
print(X_train.shape)
print(X_test.shape)
# Out:
# (11351, 9)
# (2838, 9)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error
lr=LinearRegression()
lr.fit(X_train,y_train)
pred = lr.predict(X_test)
print(pred)
print('mae=', mean_absolute_error(y_test, pred))
print('mse=', mean_squared_error(y_test, pred))
print('R^2 score (accuracy)=', lr.score(X_test, y_test))
# Out:
# [475633.83512458 471732.19099147 467456.99384367 ... 489985.66673333
#  851600.79815274 744272.41322455]
# mae= 134089.73497273284
# mse= 35680088486.79585
# R^2 score (accuracy)= 0.5233178047353069
